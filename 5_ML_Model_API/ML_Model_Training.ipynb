# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.metrics import classification_report, accuracy_score
import numpy as np

# %%
df = pd.read_csv("/content/pakistan_insurance_dataset_600.csv")

# %%
df.head()
# Out:
#    age  weight  height  income_lpa smoker        city occupation  \
# 0   26      65     187       49.32    Yes     Karachi     Doctor
# 1   44      62     154        2.18    Yes   Islamabad     Driver
# 2   32      67     171       33.85     No  Rawalpindi     Doctor
# 3   26      86     155       34.19     No  Faisalabad     Farmer
# 4   37      80     161       45.55    Yes     Karachi     Farmer
#
#   insurance_premium_category
# 0                       High
# 1                     Medium
# 2                       High
# 3                       High
# 4                       High

# %%
df.columns
# Out:
# Index(['age', 'weight', 'height', 'income_lpa', 'smoker', 'city', 'occupation',
#        'insurance_premium_category'],
#       dtype='object')

# %%
df['occupation'].unique()
# Out:
# array(['Doctor', 'Driver', 'Farmer', 'Businessman', 'Software Developer',
#        'Teacher', 'Engineer', 'Shopkeeper'], dtype=object)

# %%
df_feat = df.copy()

# %%
# Feature 1: BMI
df_feat["bmi"] = df_feat["weight"] / (df_feat["height"] ** 2)

# %%
# Feature 2: Age Group
def age_group(age):
    if age < 25:
        return "young"
    elif age < 45:
        return "adult"
    elif age < 60:
        return "middle_aged"
    return "senior"

# %%
df_feat["age_group"] = df_feat["age"].apply(age_group)

# %%
# Feature 3: Lifestyle Risk
def lifestyle_risk(row):
    if row["smoker"] and row["bmi"] > 30:
        return "high"
    elif row["smoker"] or row["bmi"] > 27:
        return "medium"
    else:
        return "low"

# %%
df_feat["lifestyle_risk"] = df_feat.apply(lifestyle_risk, axis=1)

# %%
# Tier 1 Cities (Major Metros)
tier1_cities = ["Karachi", "Lahore", "Islamabad", "Rawalpindi"]

# Tier 2 Cities (Secondary Urban Centers)
tier2_cities = [
    "Faisalabad",
    "Multan",
    "Peshawar",
    "Quetta",
    "Gujranwala",
    "Sialkot",
    "Hyderabad"
]

# %%
# Feature 4: City Tier
def city_tier(city):
    if city in tier1_cities:
        return 1
    elif city in tier2_cities:
        return 2
    else:
        return 3

# %%
df_feat["city_tier"] = df_feat["city"].apply(city_tier)

# %%
df_feat.drop(columns=['age', 'weight', 'height', 'smoker', 'city'])[['income_lpa', 'occupation', 'bmi', 'age_group', 'lifestyle_risk', 'city_tier', 'insurance_premium_category']].sample(5)
# Out:
#      income_lpa          occupation       bmi    age_group lifestyle_risk  \
# 453       36.31  Software Developer  0.001929        young         medium
# 231       19.39              Driver  0.002078        adult         medium
# 496       23.26              Driver  0.001947        adult         medium
# 428       39.20              Doctor  0.003074        adult         medium
# 385       45.24            Engineer  0.003048  middle_aged         medium
#
#      city_tier insurance_premium_category
# 453          1                     Medium
# 231          1                     Medium
# 496          1                       High
# 428          2                       High
# 385          2                        Low

# %%
df_feat["lifestyle_risk"].unique()
# Out:
# array(['medium'], dtype=object)

# %%
# Select features and target
X = df_feat[["bmi", "age_group", "lifestyle_risk", "city_tier", "income_lpa", "occupation"]]
y = df_feat["insurance_premium_category"]

# %%
X
# Out:
#           bmi    age_group lifestyle_risk  city_tier  income_lpa occupation
# 0    0.001859        adult         medium          1       49.32     Doctor
# 1    0.002614        adult         medium          1        2.18     Driver
# 2    0.002291        adult         medium          1       33.85     Doctor
# 3    0.003580        adult         medium          2       34.19     Farmer
# 4    0.003086        adult         medium          1       45.55     Farmer
# ..        ...          ...            ...        ...         ...        ...
# 595  0.002311        adult         medium          1       26.32   Engineer
# 596  0.002905        adult         medium          1       36.51     Doctor
# 597  0.002589  middle_aged         medium          2        5.02   Engineer
# 598  0.002840        adult         medium          1        8.03     Farmer
# 599  0.002828        adult         medium          2       17.54     Farmer
#
# [600 rows x 6 columns]

# %%
y
# Out:
# 0        High
# 1      Medium
# 2        High
# 3        High
# 4        High
#         ...
# 595       Low
# 596       Low
# 597       Low
# 598       Low
# 599      High
# Name: insurance_premium_category, Length: 600, dtype: object

# %%
# Define categorical and numeric features
categorical_features = ["age_group", "lifestyle_risk", "occupation", "city_tier"]
numeric_features = ["bmi", "income_lpa"]

# %%
# Create column transformer for OHE
preprocessor = ColumnTransformer(
    transformers=[
        ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_features),
        ("num", "passthrough", numeric_features)
    ]
)

# %%
# Create a pipeline with preprocessing and random forest classifier
pipeline = Pipeline(steps=[
    ("preprocessor", preprocessor),
    ("classifier", RandomForestClassifier(random_state=42))
])

# %%
# Split data and train model
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['age_group',
#                                                    'lifestyle_risk',
#                                                    'occupation', 'city_tier']),
#                                                  ('num', 'passthrough',
#                                                   ['bmi', 'income_lpa'])])),
#                 ('classifier', RandomForestClassifier(random_state=42))])

# %%
ohe = pipeline.named_steps["preprocessor"].named_transformers_["cat"]
print(ohe.categories_)
# Out:
# [array(['adult', 'middle_aged', 'senior', 'young'], dtype=object), array(['medium'], dtype=object), array(['Businessman', 'Doctor', 'Driver', 'Engineer', 'Farmer',
#        'Shopkeeper', 'Software Developer', 'Teacher'], dtype=object), array([1, 2])]

# %%
# Predict and evaluate
y_pred = pipeline.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.2916666666666667

# %%
X_test.sample(5)
# Out:
#           bmi    age_group lifestyle_risk  city_tier  income_lpa  \
# 257  0.002510       senior         medium          1       14.21
# 3    0.003580        adult         medium          2       34.19
# 90   0.002599  middle_aged         medium          2       39.86
# 499  0.002160        young         medium          2       49.18
# 293  0.002189        adult         medium          2       37.79
#
#              occupation
# 257  Software Developer
# 3                Farmer
# 90              Teacher
# 499            Engineer
# 293            Engineer

# %%
import pickle

# Save the trained pipeline using pickle
pickle_model_path = "model.pkl1"
with open(pickle_model_path, "wb") as f:
    pickle.dump(pipeline, f)
